# %%
import sys, os, re; sys.path = (["../src/", "../"] if re.match(r'^(\w\:\\)|(/)', os.getcwd()) else [])+ sys.path 

from typing import Any, Optional, List, Dict
from collections import defaultdict
import nest_asyncio
nest_asyncio.apply()

import qubx
# %qubxd dev 

# %load_ext autoreload
# %autoreload 2

import time
import tabulate
from qubx import lookup, logger
from qubx.core.basics import Position, ZERO_COSTS
from qubx.core.loggers import PositionsDumper, LogsWriter
from qubx.core.series import time_as_nsec
from qubx.core.utils import time_to_str, time_delta_to_str, recognize_timeframe
from qubx.utils.misc import makedirs
# Out:
#  >  [dev] installing cython rebuilding hook
#
# ⠀⠀⡰⡖⠒⠒⢒⢦⠀⠀
# ⠀⢠⠃⠈⢆⣀⣎⣀⣱⡀  QUBX | Quantitative Backtesting Environment
# ⠀⢳⠒⠒⡞⠚⡄⠀⡰⠁         (c) 2024, ver. 0.0.1
# ⠀⠀⠱⣜⣀⣀⣈⣦⠃⠀⠀⠀

# %%
positions = [
    Position(lookup.find_symbol('BINANCE', s), ZERO_COSTS) for s in ['BTCUSDT', 'ETHUSDT']
] 

positions[0].change_position_by(0, 0.05, 63000)
positions[1].change_position_by(0, 0.5, 3200)
# Out:
# 0

# %%
import socket
print(socket.gethostname())
# Out:
# LAPTOP-O0L8A55Q

# %%
class PositionsWriter(LogsWriter):

    def write_data(self, log_type, data: List[Dict[str, Any]]):
        table = defaultdict(list)
        total_pnl, total_mkv = 0, 0
        
        for r in data:
            table['Symbol'].append(r['instrument_id'])
            table['Time'].append(r['timestamp'])
            table['Quantity'].append(r['quantity'])
            table['AvgPrice'].append(r['avg_position_price'])
            table['LastPrice'].append(r['current_price'])
            table['PnL'].append(r['pnl_quoted'])
            table['MarketValue'].append(r['market_value_quoted'])
            total_pnl += r['pnl_quoted']
            total_mkv += r['market_value_quoted']

        table['Symbol'].append('TOTAL')
        table['PnL'].append(total_pnl)
        table['MarketValue'].append(total_mkv)

        # - write to database table here
        print(f" ::: Strategy {self.strategy_id} @ {self.account_id} :::")
        print(tabulate.tabulate(table, ['Symbol', 'Time', 'Quantity', 'AvgPrice', 'LastPrice', 'PnL', 'MarketValue'], tablefmt='rounded_grid'))

# %%
pos_dumper = PositionsDumper(PositionsWriter('test', 'strategy1', '000'), '5Sec')
pos_dumper.attach_positions(*positions)

# %%
for _ in range(30):
    t = pd.Timestamp('now').asm8
    for p in positions:
        p.update_market_price(t, p.last_update_price + 10, 1)
    pos_dumper.store(t)
    time.sleep(0.5)
# Out:
#  ::: Strategy strategy1 @ test :::
# ╭──────────┬────────────────────────────┬────────────┬────────────┬─────────────┬───────┬───────────────╮
# │ Symbol   │ Time                       │   Quantity │   AvgPrice │   LastPrice │   PnL │   MarketValue │
# ├──────────┼────────────────────────────┼────────────┼────────────┼─────────────┼───────┼───────────────┤
# │ BTCUSDT  │ 2024-04-23T16:58:19.311414 │       0.05 │      63000 │       63010 │   0.5 │        3150.5 │
# ├──────────┼────────────────────────────┼────────────┼────────────┼─────────────┼───────┼───────────────┤
# │ ETHUSDT  │ 2024-04-23T16:58:19.311414 │       0.5  │       3200 │        3210 │   5   │        1605   │
# ├──────────┼────────────────────────────┼────────────┼────────────┼─────────────┼───────┼───────────────┤
# │ TOTAL    │                            │            │            │             │   5.5 │        4755.5 │
# ╰──────────┴────────────────────────────┴────────────┴────────────┴─────────────┴───────┴───────────────╯
#  ::: Strategy strategy1 @ test :::
# ╭──────────┬────────────────────────────┬────────────┬────────────┬─────────────┬───────┬───────────────╮
# │ Symbol   │ Time                       │   Quantity │   AvgPrice │   LastPrice │   PnL │   MarketValue │
# ├──────────┼────────────────────────────┼────────────┼────────────┼─────────────┼───────┼───────────────┤
# │ BTCUSDT  │ 2024-04-23T16:58:20.313206 │       0.05 │      63000 │       63030 │   1.5 │        3151.5 │
# ├──────────┼────────────────────────────┼────────────┼────────────┼─────────────┼───────┼───────────────┤
# │ ETHUSDT  │ 2024-04-23T16:58:20.313206 │       0.5  │       3200 │        3230 │  15   │        1615   │
# ├──────────┼────────────────────────────┼────────────┼────────────┼─────────────┼───────┼───────────────┤
# │ TOTAL    │                            │            │            │             │  16.5 │        4766.5 │
# ╰──────────┴────────────────────────────┴────────────┴────────────┴─────────────┴───────┴───────────────╯
#  ::: Strategy strategy1 @ test :::
# ╭──────────┬────────────────────────────┬────────────┬────────────┬─────────────┬───────┬───────────────╮
# │ Symbol   │ Time                       │   Quantity │   AvgPrice │   LastPrice │   PnL │   MarketValue │
# ├──────────┼────────────────────────────┼────────────┼────────────┼─────────────┼───────┼───────────────┤
# │ BTCUSDT  │ 2024-04-23T16:58:25.319452 │       0.05 │      63000 │       63130 │   6.5 │        3156.5 │
# ├──────────┼────────────────────────────┼────────────┼────────────┼─────────────┼───────┼───────────────┤
# │ ETHUSDT  │ 2024-04-23T16:58:25.319452 │       0.5  │       3200 │        3330 │  65   │        1665   │
# ├──────────┼────────────────────────────┼────────────┼────────────┼─────────────┼───────┼───────────────┤
# │ TOTAL    │                            │            │            │             │  71.5 │        4821.5 │
# ╰──────────┴────────────────────────────┴────────────┴────────────┴─────────────┴───────┴───────────────╯
#  ::: Strategy strategy1 @ test :::
# ╭──────────┬────────────────────────────┬────────────┬────────────┬─────────────┬───────┬───────────────╮
# │ Symbol   │ Time                       │   Quantity │   AvgPrice │   LastPrice │   PnL │   MarketValue │
# ├──────────┼────────────────────────────┼────────────┼────────────┼─────────────┼───────┼───────────────┤
# │ BTCUSDT  │ 2024-04-23T16:58:30.324017 │       0.05 │      63000 │       63230 │  11.5 │        3161.5 │
# ├──────────┼────────────────────────────┼────────────┼────────────┼─────────────┼───────┼───────────────┤
# │ ETHUSDT  │ 2024-04-23T16:58:30.324017 │       0.5  │       3200 │        3430 │ 115   │        1715   │
# ├──────────┼────────────────────────────┼────────────┼────────────┼─────────────┼───────┼───────────────┤
# │ TOTAL    │                            │            │            │             │ 126.5 │        4876.5 │
# ╰──────────┴────────────────────────────┴────────────┴────────────┴─────────────┴───────┴───────────────╯

# %%
pos_dumper.store(pd.Timestamp('now').asm8)

# %%
pd.read_csv('logs/FlipFlopStrat_binance-mde_positions.csv', index_col=['instrument_id'], parse_dates=['timestamp'])
# Out:
#                                timestamp  pnl_quoted    quantity  \
# instrument_id
# PEPEUSDT      2024-04-24 13:41:00.363144   -0.132000  1200000.00
# SHIBUSDT      2024-04-24 13:41:00.363144   -0.254600   380000.00
# XVGUSDT       2024-04-24 13:41:00.363144    0.000000        0.00
# BOMEUSDT      2024-04-24 13:41:00.363144   -2.706572     3014.00
# CKBUSDT       2024-04-24 13:41:00.363144    0.000000        0.00
# GALAUSDT      2024-04-24 13:41:00.363144   -3.281850      429.00
# LINKUSDT      2024-04-24 13:41:00.363144   -2.683950        1.45
#
#                realized_pnl_quoted  avg_position_price  current_price  \
# instrument_id
# PEPEUSDT                       0.0            0.000008       0.000008
# SHIBUSDT                       0.0            0.000027       0.000027
# XVGUSDT                        0.0            0.000000       0.006269
# BOMEUSDT                       0.0            0.012421       0.011523
# CKBUSDT                        0.0            0.000000       0.020206
# GALAUSDT                       0.0            0.058230       0.050580
# LINKUSDT                       0.0           17.150000      15.299000
#
#                market_value_quoted                       run_id
# instrument_id
# PEPEUSDT                  9.216000  LAPTOP-O0L8A55Q-17139659532
# SHIBUSDT                 10.138400  LAPTOP-O0L8A55Q-17139659532
# XVGUSDT                   0.000000  LAPTOP-O0L8A55Q-17139659532
# BOMEUSDT                 34.730322  LAPTOP-O0L8A55Q-17139659532
# CKBUSDT                   0.000000  LAPTOP-O0L8A55Q-17139659532
# GALAUSDT                 21.698820  LAPTOP-O0L8A55Q-17139659532
# LINKUSDT                 22.183550  LAPTOP-O0L8A55Q-17139659532

# %%
pd.read_csv('logs/FlipFlopStrat_binance-mde_portfolio.csv', index_col=['timestamp'], parse_dates=['timestamp'])
# Out:
#                     instrument_id  pnl_quoted   quantity  realized_pnl_quoted  \
# timestamp
# 2024-04-23 15:35:00      PEPEUSDT    0.022800  380000.00                  0.0
# 2024-04-23 15:35:00      SHIBUSDT    0.000000       0.00                  0.0
# 2024-04-23 15:35:00       XVGUSDT    0.000000       0.00                  0.0
# 2024-04-23 15:35:00      BOMEUSDT   -4.086984    3014.00                  0.0
# 2024-04-23 15:35:00       CKBUSDT    0.000000       0.00                  0.0
# ...                           ...         ...        ...                  ...
# 2024-04-24 13:40:00       XVGUSDT    0.000000       0.00                  0.0
# 2024-04-24 13:40:00      BOMEUSDT   -2.715614    3014.00                  0.0
# 2024-04-24 13:40:00       CKBUSDT    0.000000       0.00                  0.0
# 2024-04-24 13:40:00      GALAUSDT   -3.286140     429.00                  0.0
# 2024-04-24 13:40:00      LINKUSDT   -2.701350       1.45                  0.0
#
#                      avg_position_price  current_price  market_value_quoted  \
# timestamp
# 2024-04-23 15:35:00            0.000008       0.000008              2.92980
# 2024-04-23 15:35:00            0.000000       0.000027              0.00000
# 2024-04-23 15:35:00            0.000000       0.006211              0.00000
# 2024-04-23 15:35:00            0.012421       0.011065             33.34991
# 2024-04-23 15:35:00            0.000000       0.018985              0.00000
# ...                                 ...            ...                  ...
# 2024-04-24 13:40:00            0.000000       0.006270              0.00000
# 2024-04-24 13:40:00            0.012421       0.011520             34.72128
# 2024-04-24 13:40:00            0.000000       0.020133              0.00000
# 2024-04-24 13:40:00            0.058230       0.050570             21.69453
# 2024-04-24 13:40:00           17.150000      15.287000             22.16615
#
#                                      exchange_time  commissions_quoted  \
# timestamp
# 2024-04-23 15:35:00  2024-04-23T15:36:55.276471000            0.002907
# 2024-04-23 15:35:00  2024-04-23T15:36:55.276471000            0.000000
# 2024-04-23 15:35:00  2024-04-23T15:36:55.276471000            0.000000
# 2024-04-23 15:35:00  2024-04-23T15:36:55.276471000            0.037439
# 2024-04-23 15:35:00  2024-04-23T15:36:55.276471000            0.000000
# ...                                            ...                 ...
# 2024-04-24 13:40:00  2024-04-24T13:40:00.292675000            0.000000
# 2024-04-24 13:40:00  2024-04-24T13:40:00.292675000            0.037439
# 2024-04-24 13:40:00  2024-04-24T13:40:00.292675000            0.000000
# 2024-04-24 13:40:00  2024-04-24T13:40:00.292675000            0.024985
# 2024-04-24 13:40:00  2024-04-24T13:40:00.292675000            0.024868
#
#                                           run_id
# timestamp
# 2024-04-23 15:35:00  LAPTOP-O0L8A55Q-17138865703
# 2024-04-23 15:35:00  LAPTOP-O0L8A55Q-17138865703
# 2024-04-23 15:35:00  LAPTOP-O0L8A55Q-17138865703
# 2024-04-23 15:35:00  LAPTOP-O0L8A55Q-17138865703
# 2024-04-23 15:35:00  LAPTOP-O0L8A55Q-17138865703
# ...                                          ...
# 2024-04-24 13:40:00  LAPTOP-O0L8A55Q-17139659532
# 2024-04-24 13:40:00  LAPTOP-O0L8A55Q-17139659532
# 2024-04-24 13:40:00  LAPTOP-O0L8A55Q-17139659532
# 2024-04-24 13:40:00  LAPTOP-O0L8A55Q-17139659532
# 2024-04-24 13:40:00  LAPTOP-O0L8A55Q-17139659532
#
# [392 rows x 10 columns]

# %%
pd.read_csv('logs/FlipFlopStrat_binance-mde_executions.csv', index_col=['timestamp'], parse_dates=['timestamp'])
# Out:
#                         instrument_id side  filled_qty     price  commissions  \
# timestamp
# 2024-04-23 15:36:56.355      SHIBUSDT  buy    380000.0  0.000027     0.000014
# 2024-04-23 15:37:18.561      PEPEUSDT  buy    400000.0  0.000008     0.000003
#
#                         commissions_quoted                       run_id
# timestamp
# 2024-04-23 15:36:56.355                BNB  LAPTOP-O0L8A55Q-17138865703
# 2024-04-23 15:37:18.561                BNB  LAPTOP-O0L8A55Q-17138865703

# %%
pd.read_csv('logs/FlipFlopStrat_binance-mde_balance.csv', index_col=['timestamp'], parse_dates=['timestamp'])
# Out:
#                            instrument_id          total  locked  \
# timestamp
# 2024-04-23 15:36:13.579590           BNB       0.047887     0.0
# 2024-04-23 15:36:13.579590          USDT      60.669210     0.0
# 2024-04-23 15:36:13.579590          LINK       1.450000     0.0
# 2024-04-23 15:36:13.579590          GALA     429.000000     0.0
# 2024-04-23 15:36:13.579590          ETHW       0.024330     0.0
# 2024-04-23 15:36:13.579590          PEPE  380000.000000     0.0
# 2024-04-23 15:36:13.579590          BOME    3014.000000     0.0
#
#                                                  run_id
# timestamp
# 2024-04-23 15:36:13.579590  LAPTOP-O0L8A55Q-17138865703
# 2024-04-23 15:36:13.579590  LAPTOP-O0L8A55Q-17138865703
# 2024-04-23 15:36:13.579590  LAPTOP-O0L8A55Q-17138865703
# 2024-04-23 15:36:13.579590  LAPTOP-O0L8A55Q-17138865703
# 2024-04-23 15:36:13.579590  LAPTOP-O0L8A55Q-17138865703
# 2024-04-23 15:36:13.579590  LAPTOP-O0L8A55Q-17138865703
# 2024-04-23 15:36:13.579590  LAPTOP-O0L8A55Q-17138865703
